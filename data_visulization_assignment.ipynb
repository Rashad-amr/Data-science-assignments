# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib as plt

# %%
df=pd.read_csv('50ulke.csv')
df.drop('Unnamed: 0',inplace=True,axis=1)

# %%
df
# Out:
#                    Countries  National Income  Growth  Per person  \
# 0              United States         20412.87    2.27     62152.0
# 1                      China         14092.51    6.86     10088.0
# 2                      Japan          5167.05    1.71     40849.0
# 3                    Germany          4211.64    2.51     50842.0
# 4             United Kingdom          2936.29    1.79     44177.0
# 5                     France          2925.10    1.85     44934.0
# 6                      India          2848.23    6.74      2135.0
# 7                      Italy          2181.97    1.47     35914.0
# 8                     Brazil          2138.92    0.98     10224.0
# 9                     Canada          1798.51    3.00     48466.0
# 10                    Russia          1719.90    1.55     11947.0
# 11                     Korea          1693.25    3.09     32775.0
# 12                     Spain          1506.44    3.05     32559.0
# ...

# %%
sns.violinplot(x='Continent',y='Growth',data=df);

# %% [markdown]
# >> it show that Asia is the most Continent in the growth and Europe secoend with denisty withen (2,3) and north amierca density withen (2,4)

# %%
sns.boxplot(x='Continent',y='Growth',data=df);

# %% [markdown]
# >> like the up but it doesn't show density but show that Aisa,Europe,south amirca,africa and north america and,oceania with no growth

# %%
sns.scatterplot(x='Continent',y='National Income',data=df)

# %%
sns.boxplot(x='Continent',y='National Income',data=df)

# %% [markdown]
# >> its show that North america has the most National income and Europe the secoend

# %%
sns.countplot(df['Continent'])

# %% [markdown]
# >> its show that the most countries in Asia and Europe and least in oceania

# %%
sns.catplot(x='Continent',y='Per person',kind='box',data=df,height=5, aspect=1.3)
